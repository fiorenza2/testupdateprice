# %%
import sys
print(sys.version)
# Out:
# 3.5.2 |Anaconda custom (x86_64)| (default, Jul  2 2016, 17:52:12)
# [GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]

# %%
from bs4 import BeautifulSoup
import requests

page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")
page
# Out:
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %%
len(list(soup.children))
# Out:
# 3

# %%
tpage = requests.get("http://uk.tommy.com/Printed-Slim-Fit-Shirt/MW0MW01907,en_GB,pd.html?cgid=206000#!color%3D485%26size%3DS")
page
# Out:
# <Response [200]>

# %%
tommy = BeautifulSoup(tpage.content, 'html.parser')
print(tommy.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <head>
#   <title>
#    Printed Slim Fit Shirt | Blue | Tommy Hilfiger® | 8719255378759
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script src="http://demandware.edgesuite.net/aadj_prd/on/demandware.static/Sites-GB-Site/-/en_GB/v1495750717088/js/ext/jquery-1.7.2.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    @font-face {
# 	    font-family: 'caslon_540italic';
# 	    src: url('http://uk.tommy.com/fonts/caslonitalic-webfont.woff2') format('woff2'),
# 	        url('http://uk.tommy.com/fonts/caslonitalic-webfont.woff')  format('woff');
# 	}
# 	@font-face {
# 	    font-family: 'caslon_540regular';
# 	    src: url('http://uk.tommy.com/fonts/caslon-webfont.woff2') format('woff2'),
# ...

# %%
pricearea = tommy.find('div', class_="allVariants")
pricearea
# Out:
# <div class="allVariants">
# <div class="color selected" data-colorid="485" data-variantid="8719255378759" id="color_485">
# <div class="variantContent">
# <div class="variantDetails">
# <div class="pricing">
# <div class="price">
# <div class="salesprice ">£ 75.00</div>
# <div class="clear"><!-- empty --></div>
# </div>
# </div>
# <div class="product_info_taxation">
# 						(inc. VAT)
# 					</div>
# <div class="staticmsg">
# 		Enjoy free delivery on all orders over £50
# 	</div>
# <div class="overlayContainer">
# <div class="addToCartForm">
# <div class="colorVariations color-chips-block">
# <div class="swatchesdisplay color-block">
# <span class="swatches-label">Color</span>
# <div class="color-size-message">
# <span class="swatches-label">:</span>
# <span class="label value selectedvarval">Medieval Blue (Blue)</span>
# </div>
# <ul>
# <li class="selected">
# ...

# %%
pricearea.find('div', class_="salesprice ").get_text()
# Out:
# '£ 75.00'

# %%
tpage2 = requests.get("http://uk.tommy.com/Cotton-Printed-Crew-Neck-T-shirt/MW0MW00193,en_GB,pd.html?cgid=SPECIAL-PROMO-MEN#!color%3D491%26size%3DS")

# %%
tommy2 = BeautifulSoup(tpage2.content, 'html.parser')

# %%
pricearea2 = tommy2.find('div', class_="allVariants")
pricearea2
# Out:
# <div class="allVariants">
# <div class="color selected" data-colorid="491" data-variantid="8719253423796" id="color_491">
# <div class="variantContent">
# <div class="variantDetails">
# <div class="pricing">
# <div class="price">
# <div class="standardprice">£ 35.00</div>
# <div class="salesprice sales-price">£ 24.50</div>
# <div class="clear"><!-- empty --></div>
# </div>
# </div>
# <div class="product_info_taxation">
# 						(inc. VAT)
# 					</div>
# <div class="staticmsg">
# 		Enjoy free delivery on all orders over £50
# 	</div>
# <div class="overlayContainer">
# <div class="addToCartForm">
# <div class="colorVariations color-chips-block">
# <div class="swatchesdisplay color-block">
# <span class="swatches-label">Color</span>
# <div class="color-size-message">
# <span class="swatches-label">:</span>
# <span class="label value selectedvarval">Surf the Web (Blue)</span>
# </div>
# <ul>
# <li class="selected">
# ...
